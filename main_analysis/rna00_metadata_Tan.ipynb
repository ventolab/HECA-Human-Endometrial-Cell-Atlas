# %% [markdown]
# # Endometriosis analysis
# ## Extract metadata from Tan et al 2022

# %%
import scrublet as scr
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import os
import sys
import scipy


def MovePlots(plotpattern, subplotdir):
    os.system('mkdir -p '+str(sc.settings.figdir)+'/'+subplotdir)
    os.system('mv '+str(sc.settings.figdir)+'/*'+plotpattern+'** '+str(sc.settings.figdir)+'/'+subplotdir)


sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.figdir = './figures/'
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures

sys.executable
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.7.1
# sinfo       0.3.1
# -----
# PIL                 8.1.2
# anndata             0.7.5
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.6.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.03.1
# dateutil            2.8.1
# decorator           4.4.2
# fsspec              0.8.7
# get_version         2.1
# google              NA
# h5py                3.1.0
# idna                2.10
# igraph              0.8.3
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.3.0
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.34.0
# louvain             0.7.0
# markupsafe          1.1.1
# matplotlib          3.3.4
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.51.2
# numexpr             2.7.3
# numpy               1.20.1
# packaging           20.9
# pandas              1.2.3
# parso               0.8.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pyarrow             0.16.0
# pygments            2.8.0
# pyparsing           2.4.7
# pyrsistent          NA
# pytoml              NA
# pytz                2021.1
# requests            2.25.1
# ruamel              NA
# scanpy              1.7.1
# scipy               1.6.1
# scrublet            NA
# send2trash          NA
# setuptools_scm      NA
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.24.1
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# storemagic          NA
# tables              3.6.1
# tblib               1.7.0
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.3.1
# zmq                 22.0.3
# -----
# IPython             7.21.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.9
# notebook            6.2.0
# -----
# Python 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27) [GCC 9.3.0]
# Linux-4.15.0-158-generic-x86_64-with-glibc2.10
# 60 logical CPU cores, x86_64
# -----
# Session information updated at 2022-08-16 09:23
# '/opt/conda/bin/python'

# %% [markdown]
# ## All cells

# %%
path2datas = '/nfs/team292/lg18/endometriosis/other_datasets/endometriosis_Tan2022/'
adata = sc.read(path2datas+'endo-2022_global.h5ad')
adata.X.shape
# Out:
# (108497, 26636)

# %%
sampleID = [ i + '_' for i in adata.obs.PID ]
sampleID = [a + b for a, b in zip(sampleID, adata.obs.sample_type_rename.tolist())]
adata.obs['sample'] = sampleID

# %%
len(set(sampleID))
# Out:
# 30

# %%
adata.obs.head()
# Out:
#                       sequencing_saturation stage  n_genes_by_counts  \
# index
# AAACCCAAGACCAAGC-1-0              77.036286     0               1748
# AAACCCACAACTCGTA-1-0              77.165551     0               4166
# AAACCCAGTAATCAGA-1-0              70.605258     0               4440
# AAACCCAGTTTGAACC-1-0              73.311330     0               3623
# AAACCCATCACAACCA-1-0              77.666907     0               4687
#
#                       total_counts  pct_counts_mitochondrial  \
# index
# AAACCCAAGACCAAGC-1-0        4759.0                 23.891575
# AAACCCACAACTCGTA-1-0       15553.0                 11.091108
# AAACCCAGTAATCAGA-1-0       15541.0                 14.374879
# AAACCCAGTTTGAACC-1-0       13019.0                 13.572471
# AAACCCATCACAACCA-1-0       16137.0                  6.358059
#
#                       pct_counts_hemoglobin      celltype celltype_main  \
# index
# AAACCCAAGACCAAGC-1-0                    0.0  fibroblast 1       stromal
# AAACCCACAACTCGTA-1-0                    0.0  fibroblast 1       stromal
# AAACCCAGTAATCAGA-1-0                    0.0     myeloid 3       myeloid
# AAACCCAGTTTGAACC-1-0                    0.0     myeloid 1       myeloid
# AAACCCATCACAACCA-1-0                    0.0  fibroblast 1       stromal
#
#                      sample_type_rename  PID  G2M_score phase   sample
# index
# AAACCCAAGACCAAGC-1-0                EuE  E01  -0.044748    G1  E01_EuE
# AAACCCACAACTCGTA-1-0                EuE  E01  -0.146015    G1  E01_EuE
# AAACCCAGTAATCAGA-1-0                EuE  E01  -0.117621    G1  E01_EuE
# AAACCCAGTTTGAACC-1-0                EuE  E01  -0.184900    G1  E01_EuE
# AAACCCATCACAACCA-1-0                EuE  E01  -0.076091    G1  E01_EuE

# %%
adata.obs.to_csv('metadata-Tan2022.csv')

# %% [markdown]
# ## Epithelial cells

# %%
adata = sc.read(path2datas+'endo-2022_epithelial.h5ad')
adata.X.shape
# Out:
# (19200, 24231)

# %%
sampleID = [ i + '_' for i in adata.obs.PID ]
sampleID = [a + b for a, b in zip(sampleID, adata.obs.sample_type_rename.tolist())]
adata.obs['sample'] = sampleID

# %%
adata.obs.head()
# Out:
#                       sequencing_saturation stage  n_genes_by_counts  \
# index
# AAAGGATCAAGTGCTT-1-0              73.772996     0               3012
# AAAGTGAAGATCACCT-1-0              76.680133     0               3547
# AACACACTCATTATCC-1-0              76.339873     0               6934
# AACGAAAAGGCACAAC-1-0              75.519513     0               5734
# AACGGGATCAGGGATG-1-0              76.992985     0               8944
#
#                       total_counts  pct_counts_mitochondrial  \
# index
# AAAGGATCAAGTGCTT-1-0        8069.0                 10.397819
# AAAGTGAAGATCACCT-1-0       12353.0                 12.239942
# AACACACTCATTATCC-1-0       40641.0                  8.240447
# AACGAAAAGGCACAAC-1-0       26836.0                 22.525711
# AACGGGATCAGGGATG-1-0       60479.0                 13.234345
#
#                       pct_counts_hemoglobin      celltype celltype_main  \
# index
# AAAGGATCAAGTGCTT-1-0                    0.0  epithelial 2    epithelial
# AAAGTGAAGATCACCT-1-0                    0.0  epithelial 2    epithelial
# AACACACTCATTATCC-1-0                    0.0  epithelial 2    epithelial
# AACGAAAAGGCACAAC-1-0                    0.0  epithelial 2    epithelial
# AACGGGATCAGGGATG-1-0                    0.0  epithelial 2    epithelial
#
#                          subtypes sample_type_rename  PID  G2M_score phase  \
# index
# AAAGGATCAAGTGCTT-1-0    glandular                EuE  E01  -0.201646    G1
# AAAGTGAAGATCACCT-1-0    lumenal 1                EuE  E01  -0.160264    G1
# AACACACTCATTATCC-1-0    glandular                EuE  E01  -0.208345     S
# AACGAAAAGGCACAAC-1-0  TP63+/KRT5+                EuE  E01  -0.162246    G1
# AACGGGATCAGGGATG-1-0      lumenal                EuE  E01  -0.188662     S
#
#                        sample
# index
# AAAGGATCAAGTGCTT-1-0  E01_EuE
# AAAGTGAAGATCACCT-1-0  E01_EuE
# AACACACTCATTATCC-1-0  E01_EuE
# AACGAAAAGGCACAAC-1-0  E01_EuE
# AACGGGATCAGGGATG-1-0  E01_EuE

# %%
adata.obs.to_csv('metadata-Tan2022_epithelials.csv')

# %% [markdown]
# ## Endothelial cells

# %%
adata = sc.read(path2datas+'endo-2022_endothelial.h5ad')
adata.X.shape
# Out:
# (10751, 21391)

# %%
sampleID = [ i + '_' for i in adata.obs.PID ]
sampleID = [a + b for a, b in zip(sampleID, adata.obs.sample_type_rename.tolist())]
adata.obs['sample'] = sampleID

# %%
adata.obs.head()
# Out:
#                       sequencing_saturation stage  n_genes_by_counts  \
# index
# AACCTTTAGTATGACA-1-0              75.917320     0               5859
# AACGGGAGTTCAAAGA-1-0              77.667494     0               4078
# AAGACTCGTACGTAGG-1-0              75.781388     0               4926
# AAGCATCTCTCTTGCG-1-0              75.797038     0               4187
# ACAAAGAGTCGTGCCA-1-0              74.414753     0               3757
#
#                       total_counts  pct_counts_mitochondrial  \
# index
# AACCTTTAGTATGACA-1-0       22801.0                 10.324108
# AACGGGAGTTCAAAGA-1-0       13320.0                  7.004505
# AAGACTCGTACGTAGG-1-0       17845.0                  9.756234
# AAGCATCTCTCTTGCG-1-0       13809.0                 13.194294
# ACAAAGAGTCGTGCCA-1-0       11432.0                 13.794611
#
#                       pct_counts_hemoglobin     celltype celltype_main  \
# index
# AACCTTTAGTATGACA-1-0                    0.0  endothelial   endothelial
# AACGGGAGTTCAAAGA-1-0                    0.0  endothelial   endothelial
# AAGACTCGTACGTAGG-1-0                    0.0  endothelial   endothelial
# AAGCATCTCTCTTGCG-1-0                    0.0  endothelial   endothelial
# ACAAAGAGTCGTGCCA-1-0                    0.0  endothelial   endothelial
#
#                      subtypes sample_type_rename  PID  G2M_score phase  \
# index
# AACCTTTAGTATGACA-1-0   EC-HEV                EuE  E01  -0.083001    G1
# AACGGGAGTTCAAAGA-1-0   EC-HEV                EuE  E01  -0.104489    G1
# AAGACTCGTACGTAGG-1-0   EC-tip                EuE  E01  -0.076667    G1
# AAGCATCTCTCTTGCG-1-0   EC-HEV                EuE  E01  -0.118619    G1
# ACAAAGAGTCGTGCCA-1-0      LEC                EuE  E01  -0.070855    G1
#
#                        sample
# index
# AACCTTTAGTATGACA-1-0  E01_EuE
# AACGGGAGTTCAAAGA-1-0  E01_EuE
# AAGACTCGTACGTAGG-1-0  E01_EuE
# AAGCATCTCTCTTGCG-1-0  E01_EuE
# ACAAAGAGTCGTGCCA-1-0  E01_EuE

# %%
adata.obs.to_csv('metadata-Tan2022_endothelial.csv')

# %% [markdown]
# ## Mesenchymal cells

# %%
adata = sc.read(path2datas+'endo-2022_stromal.h5ad')
adata.X.shape
# Out:
# (42713, 24401)

# %%
sampleID = [ i + '_' for i in adata.obs.PID ]
sampleID = [a + b for a, b in zip(sampleID, adata.obs.sample_type_rename.tolist())]
adata.obs['sample'] = sampleID

# %%
adata.obs.to_csv('metadata-Tan2022_mesenchymal.csv')
