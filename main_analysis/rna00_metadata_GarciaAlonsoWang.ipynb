# %% [markdown]
# # Endometriosis analysis
# ## Extract metadata from GarciaAlonso et al 2021

# %%
import scrublet as scr
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import os
import sys
import scipy


def MovePlots(plotpattern, subplotdir):
    os.system('mkdir -p '+str(sc.settings.figdir)+'/'+subplotdir)
    os.system('mv '+str(sc.settings.figdir)+'/*'+plotpattern+'** '+str(sc.settings.figdir)+'/'+subplotdir)


sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.figdir = './figures/'
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures

sys.executable

# %% [markdown]
# ## All cells

# %%
path2datas = '/nfs/team292/lg18/endometriosis/other_datasets/endometrium_GarciaAlonso2021/'
adata = sc.read(path2datas+'endometrium_all.h5ad')
adata.X.shape
# Out:
# (100307, 28614)

# %%
adata.obs.head()
# Out:
#                                          SampleID  log2p1_count  percent_mito  \
# 4861STDY7387181_AAACCTGAGGCATGGT  4861STDY7387181     13.951467      0.057320
# 4861STDY7387181_AAACCTGAGGGCACTA  4861STDY7387181     13.776227      0.043838
# 4861STDY7387181_AAACCTGAGTGAAGTT  4861STDY7387181     12.894628      0.070791
# 4861STDY7387181_AAACCTGAGTGGGCTA  4861STDY7387181     12.329235      0.071137
# 4861STDY7387181_AAACCTGCACCGAAAG  4861STDY7387181     12.171176      0.063977
#
#                                   n_genes DonorID   BiopsyType  \
# 4861STDY7387181_AAACCTGAGGCATGGT     3842     A13  Organ_Donor
# 4861STDY7387181_AAACCTGAGGGCACTA     3544     A13  Organ_Donor
# 4861STDY7387181_AAACCTGAGTGAAGTT     2507     A13  Organ_Donor
# 4861STDY7387181_AAACCTGAGTGGGCTA     1928     A13  Organ_Donor
# 4861STDY7387181_AAACCTGCACCGAAAG     1824     A13  Organ_Donor
#
#                                               Location   Binary Stage  \
# ...

# %%
adata.obs.to_csv('metadata-GarciaAlonso2021.csv')

# %% [markdown]
# ## Epi cells

# %%
path2datas = '/nfs/team292/lg18/endometriosis/other_datasets/endometrium_GarciaAlonso2021/'
adata = sc.read(path2datas+'endometrium_epithelial.h5ad')
adata.X.shape
# Out:
# (10729, 28614)

# %%
adata.obs.head()
# Out:
#                                          SampleID  log2p1_count  percent_mito  \
# 4861STDY7387181_AAACCTGTCAATAAGG  4861STDY7387181     13.270441      0.081781
# 4861STDY7387181_AAACCTGTCTTGCCGT  4861STDY7387181     14.328886      0.089513
# 4861STDY7387181_AAACGGGAGTATCGAA  4861STDY7387181     14.863364      0.094578
# 4861STDY7387181_AAACGGGTCAGATAAG  4861STDY7387181     13.653741      0.097851
# 4861STDY7387181_AAAGATGCAACAACCT  4861STDY7387181     15.457316      0.090022
#
#                                   n_genes DonorID   BiopsyType  \
# 4861STDY7387181_AAACCTGTCAATAAGG     2594     A13  Organ_Donor
# 4861STDY7387181_AAACCTGTCTTGCCGT     4900     A13  Organ_Donor
# 4861STDY7387181_AAACGGGAGTATCGAA     5237     A13  Organ_Donor
# 4861STDY7387181_AAACGGGTCAGATAAG     3465     A13  Organ_Donor
# 4861STDY7387181_AAAGATGCAACAACCT     7172     A13  Organ_Donor
#
#                                               Location   Binary Stage  \
# ...

# %%
adata.obs.to_csv('metadata-GarciaAlonso2021_epithelial.csv')
